# %%
import pandas as pd

# Load the data
np_data = pd.read_csv('~/scRNA-seq/final/4-nmf/2-nmf_sample_program_int/NPs_int_qc.csv')

# Calculate overlaps
def calculate_overlaps(data):
    overlaps = pd.DataFrame(index=data.columns, columns=data.columns)
    for col1 in data.columns:
        for col2 in data.columns:
            overlaps.at[col1, col2] = len(set(data[col1].dropna()).intersection(set(data[col2].dropna())))
    return overlaps

overlaps = calculate_overlaps(np_data.iloc[:, 1:])

# %%
# Form cluster based on overlaps and return the Meta Program for the cluster
def form_cluster_v3(overlaps, data, threshold=20, cluster_size=10, mp_size=50):
    founder = overlaps[overlaps >= threshold].count(axis=1).idxmax()
    overlapping_programs = overlaps[founder][overlaps[founder] >= threshold].index.tolist()
    if len(overlapping_programs) < cluster_size:
        return [], []
    cluster = [founder]
    mp_genes = list(data[founder].dropna())
    while overlapping_programs:
        overlaps_with_mp = overlaps.loc[overlapping_programs, cluster].sum(axis=1)
        next_program = overlaps_with_mp.idxmax()
        cluster.append(next_program)
        mp_genes += list(data[next_program].dropna())
        mp_genes = mp_genes[:mp_size]
        overlapping_programs.remove(next_program)
    return cluster, mp_genes

# Form multiple clusters and return the associated Meta Programs
def form_clusters_v4(overlaps, data, threshold=20, cluster_size=10):
    clusters = []
    while not overlaps.empty:
        cluster, mp = form_cluster_v3(overlaps, data, threshold=threshold, cluster_size=cluster_size)
        if not cluster:
            break
        clusters.append((cluster, mp))
        overlaps = overlaps.drop(cluster, axis=1).drop(cluster, axis=0)
    return clusters

clusters = form_clusters_v4(overlaps, np_data.iloc[:, 1:], threshold=25, cluster_size=10)

# Format and save the results to a CSV
formatted_df_v5 = pd.DataFrame()

# Determine the maximum number of NMF programs across all clusters
max_programs_count = max(len(cluster_programs) for cluster_programs, _ in clusters)

for idx, (cluster_programs, mp_genes) in enumerate(clusters):
    formatted_df_v5[f'MP{idx+1}_Gene'] = mp_genes + [None] * (max_programs_count - len(mp_genes))
    formatted_df_v5[f'MP{idx+1}'] = cluster_programs + [None] * (max_programs_count - len(cluster_programs))

# %%
# Copy the list of column names to avoid modifying it during iteration
original_columns = formatted_df_v5.columns.tolist()

# Update column names
new_columns = []
for col in original_columns:
    if 'MP' is in col and '_Gene' is not in col:  # Ensure it's an MP column and exclude columns ending with _Gene
        # Calculate the number of unique non-null elements
        unique_count = formatted_df_v5[col].nunique()
        # Add the count to the column name
        new_col_name = f"{col} ({unique_count})"
        new_columns.append(new_col_name)
    else:
        # For columns that don't need modification, keep them unchanged
        new_columns.append(col)
# Apply the new column names
formatted_df_v5.columns = new_columns
formatted_df_v5.to_csv("./mp_clusters_and_nmfs.csv", index=False)

# %%
formatted_df_v5.head(50)
# Out:
#      MP1_Gene      MP1 (75)   MP2_Gene      MP2 (71)  MP3_Gene      MP3 (62)  \
# 0     mt-Cytb    k10_D65.V3      Hmgb2    k10_BL8.V9      Ier2    k8_EL29.V7
# 1        Spp1    k10_D65.V3      Ube2c    k10_BL8.V9    Dnajb1    k8_EL29.V7
# 2        Fth1    k12_D65.V2      Cenpf   k12_D44.V11      Klf2   k10_AL51.V2
# 3       H2-D1   k10_EL27.V6       Prc1     k8_BL4.V7       Fos   k10_OX66.V1
# 4      mt-Co1    k8_VL11.V1      Top2a    k12_BL4.V7      Egr1   k10_YM42.V9
# 5         Dcn  k10_OX67.V10       Smc4   k12_BL12.V6     Dusp1   k10_OX67.V2
# 6         Ubb    k8_VL71.V5      H2afz    k8_AL32.V7    Nfkbia    k8_OX67.V7
# 7       Itm2b   k12_AL51.V2      Tubb5  k12_AL38.V11     Zfp36   k12_OX67.V1
# 8      Malat1   k12_EL27.V9      Mki67    k12_BL8.V4      Ccn1   k10_YM47.V6
# 9       Rpl32    k8_VL12.V6   Hist1h1b    k12_D24.V7      Junb    k8_YM47.V4
# 10      Rpl41   k10_VL12.V8  Hist1h2ap     k8_D24.V4       Jun    k8_VL12.V3
# 11       Ftl1   k12_EL28.V5      Birc5     k8_D44.V2      Klf6    k8_OX71.V7
# 12     Ifitm3   k10_VL71.V9       Anln    k10_D44.V1       Ubc  k10_VL12.V10
# 13     mt-Nd4  k12_YM47.V11      Hmgb1   k10_BL12.V9    Phlda1    k8_EL27.V2
# 14     mt-Nd1    k8_AL51.V7       Cks2    k10_BL4.V3   mt-Cytb   k12_YM42.V5
# 15       Cst3   k10_OX66.V6     Tubb4b   k10_AL38.V5      Fosb  k10_EL27.V10
# 16        B2m   k10_YM42.V5      Ube2s    k10_D24.V5       Ubb   k12_OX71.V8
# 17     mt-Nd5    k8_OX67.V3   Hist1h1e   k10_AL32.V9      Jund  k12_OX66.V11
# 18      Rps19    k8_YM47.V5    Racgap1     k8_BL8.V2      Plk2   k12_VL12.V9
# 19     Rpl18a  k12_OX66.V12       Tpx2    k8_YM12.V7     Cxcl1   k12_EL27.V8
# 20     Eef1a1    k8_OX66.V1      Cenpe   k10_YM12.V5       Mt1    k8_YM42.V3
# 21      H2-K1   k12_YM42.V1      Cks1b   k10_NE31.V5  Hsp90ab1    k10_D65.V5
# 22        Mt1   k12_VL71.V9  Hist1h2ae   k10_NE29.V8  Hsp90aa1    k12_D65.V5
# 23    Gm10260    k8_EL28.V4       Tpt1    k8_NE29.V2    Lgals1   k12_VL71.V8
# 24     Gm2000   k10_YM47.V4       Ly6e   k12_NE31.V9     Hspa5    k8_AL51.V2
# 25      Rplp1    k8_OX71.V6      Stmn1  k12_NE29.V10    mt-Nd1   k12_YM47.V5
# 26       Rps5   k10_VL11.V7        Vim   k12_YM12.V4      Klf4    k8_VL11.V3
# 27    Gm42418   k12_OX71.V9       Hmmr  k10_NE33.V10    Ifitm3    k8_EL28.V6
# 28        Fn1   k10_AL51.V7       Ptma    k8_OX71.V8      Actb  k10_EL28.V10
# 29       Rps9   k10_EL29.V9    Selenoh   k12_EL27.V1     Rpl41   k12_EL28.V4
# 30     mt-Nd2     k8_D65.V1       Smc2    k8_OX67.V2    Malat1  k12_VL11.V11
# 31     S100a6    k8_EL29.V5       Rps8   k10_OX71.V1    mt-Co1   k10_VL11.V1
# 32       Cd63   k12_VL11.V2      Cenpa    k8_YM47.V1     Rpl32    k8_VL71.V2
# 33  Rps18-ps5   k10_EL28.V2      Rps20   k12_YM42.V7    mt-Nd4  k10_OX71.V10
# 34       Rpl4   k10_NE31.V6     Tuba1b   k12_NE33.V6      Lmna  k10_VL71.V10
# 35      Rps26   k12_AL32.V9      Calm2   k10_EL29.V5   Adamts1  k12_AL51.V12
# 36     Ifitm1  k12_EL29.V12       Tmpo  k12_VL71.V12       B2m  k10_EL29.V10
# 37     Lgals1  k12_VL12.V12     Eef1a1   k12_YM47.V8    Rpl18a   k12_BL8.V12
# 38    Rps27rt  k12_NE29.V12     Lgals1   k10_AL51.V9    S100a6   k10_AL51.V6
# 39      Rpl34   k12_VL11.V3      Rpl13   k10_EL27.V4    mt-Nd2   k12_YM42.V2
# 40       Eif1  k12_EL29.V11      Rad21   k12_EL28.V1     Hspe1   k12_EL29.V6
# 41     Tecpr2   k12_AL51.V3     Nusap1    k12_D65.V7       Vim     k8_BL8.V7
# 42      Rplp0    k8_YM12.V4     Rps3a1   k12_AL51.V4      Rhob    k10_BL8.V5
# 43       Aspn    k12_D24.V6      Rpl41  k12_OX71.V11     H3f3b  k12_BL12.V11
# 44      Rps20    k8_EL28.V8      H2afv    k10_D65.V1    Dnaja1   k10_VL71.V6
# 45      Rpl18    k8_YM47.V8      Rpl32   k10_OX66.V4       Mt2    k8_AL32.V6
# 46   Tmem176b   k12_YM47.V9       Rps5   k10_VL11.V4     Rps26    k8_AL38.V8
# 47        Ogn  k10_VL11.V10       Actb   k10_OX67.V7   Gadd45g    k10_D24.V6
# 48     Pcolce   k10_OX66.V2     Nucks1   k12_OX67.V4      Sat1  k10_AL32.V10
# 49       Rps3   k10_YM47.V9      Cdca8   k10_VL12.V7     Rps19   k10_AL38.V1
#
#      MP4_Gene      MP4 (38)       MP5_Gene      MP5 (35)  ...  MP8_Gene  \
# 0         Ncl  k12_YM42.V11           Lig1   k10_VL11.V3  ...      Eef2
# 1     Slc25a5  k12_YM42.V11           Pcna   k10_VL11.V3  ...     Ahnak
# 2       Eif5a   k12_OX66.V4           Rrm2   k10_AL51.V3  ...    Pabpc1
# 3        Actb    k8_OX66.V2          Pclaf    k8_OX71.V1  ...      Calu
# 4      Lgals1    k8_OX67.V4            Dek    k8_YM47.V6  ...       Vim
# 5     S100a11    k8_VL12.V4           Mcm2   k10_OX67.V5  ...    Eef1a1
# 6     mt-Cytb   k12_EL28.V7         Tuba1b    k8_OX67.V1  ...     Rack1
# 7         Ran   k10_VL71.V2          Cenph   k12_VL11.V8  ...  Hsp90ab1
# 8      mt-Nd1    k8_EL27.V1           Mcm6   k12_EL29.V7  ...  Hsp90aa1
# 9         Srm     k8_D65.V3  1810037I17Rik   k10_VL12.V6  ...      Rpsa
# 10      Rpl41   k12_VL12.V6          Tubb5   k10_EL27.V5  ...   Hsp90b1
# 11      H2-D1  k10_OX66.V10           Ptma   k10_EL28.V3  ...  Baiap2l1
# 12  Hnrnpa2b1   k10_OX71.V3        Slc25a5   k10_OX66.V7  ...    Col1a2
# 13     Cacybp    k8_YM47.V3           Rfc2  k12_VL71.V10  ...    Eif4g2
# 14       Pfn1   k10_EL28.V9           Mcm7  k12_EL28.V12  ...      Ctsl
# 15    Hsp90b1   k10_VL11.V6           Rpa3   k10_OX71.V2  ...       Ubc
# 16       Npm1  k10_AL51.V10         Mrpl18   k12_VL12.V7  ...       Ank
# 17      Hspe1    k8_VL11.V4           Tyms   k12_AL51.V5  ...    Nap1l1
# 18      Calm1   k10_VL12.V4         Ranbp1   k12_OX67.V7  ...     Eif3a
# 19      Ccnd1    k8_EL29.V6          Rpl41  k12_YM42.V12  ...       Fn1
# 20       Calr   k12_YM47.V4          Siva1  k12_EL27.V12  ...     Nedd4
# 21       Mdh2    k8_YM42.V2            Tk1  k12_YM47.V12  ...    Malat1
# 22      Hspa5    k8_AL51.V5           Cdk4    k12_D65.V4  ...    Ptp4a2
# 23   Hsp90ab1   k12_VL11.V4           Npm1    k8_EL28.V3  ...     Mbnl1
# 24      Rpl32   k12_OX67.V3         Lgals1     k8_D65.V4  ...     Luc7l
# 25     Eif2s2   k12_VL71.V1           Cbx5   k12_YM12.V8  ...       Tpr
# 26     S100a6    k8_EL28.V7          Asf1b    k8_YM12.V6  ...      Canx
# 27      Nop58    k8_NE31.V5          H2az1   k10_YM42.V4  ...      Spp1
# 28      Hspd1   k12_EL29.V5          Prdx1  k12_OX66.V10  ...     Itgb1
# 29   Serpinh1   k10_NE29.V9          Hells    k8_NE31.V2  ...      Emp1
# 30      Psma7    k8_NE33.V6            Ubb   k12_NE29.V1  ...      Cav1
# 31      Banf1    k8_OX71.V3          Banf1   k12_NE31.V7  ...      Ssr3
# 32       Lyar    k10_BL4.V5         Ndufa4   k10_NE29.V7  ...    Hnrnpu
# 33      Anxa2  k12_NE31.V12          Atad2    k10_D65.V7  ...      Rpl8
# 34       Cfl1    k10_D65.V2          Psma7    k8_VL71.V3  ...    Eef1b2
# 35       Nhp2   k12_OX67.V5          Hint1    k8_VL11.V2  ...    Rps3a1
# 36       Ptma   k12_YM47.V6           Rfc1          None  ...     Rps4x
# 37      Rps26    k12_D65.V8          Slfn9          None  ...      Rpl7
# 38       Rps5   k10_EL29.V3            Dut          None  ...       Axl
# 39     Ndufa4          None          Hmgb2          None  ...     H2-D1
# 40       Ybx3          None        Gm10260          None  ...    Sptbn1
# 41      Rps11          None          Rbbp7          None  ...   Sh3glb1
# 42      Uqcrq          None           Mcm3          None  ...      Scd1
# 43     Pabpc1          None        mt-Cytb          None  ...      Fth1
# 44     Serbp1          None          Dtymk          None  ...       B2m
# 45       Txn1          None           Hat1          None  ...       Ncl
# 46     Snrpd3          None          Paics          None  ...     Hspd1
# 47       Cct5          None         Uqcr10          None  ...     Ywhaz
# 48       Cnbp          None        Slc25a4          None  ...     Hspa9
# 49     Anp32b          None           Cd81          None  ...     Eif3e
#
#         MP8 (19)  MP9_Gene      MP9 (14) MP10_Gene     MP10 (13) MP11_Gene  \
# 0    k12_VL71.V3    Malat1     k8_BL4.V3      Spp1   k12_EL28.V6      Pcna
# 1    k12_VL71.V3   mt-Atp6     k8_BL4.V3       Cd9   k12_EL28.V6      Ptma
# 2     k12_D65.V9    mt-Co3  k10_AL38.V10     Anxa1   k10_EL28.V8     H2afz
# 3    k10_VL11.V8    mt-Co1    k8_BL12.V7   Tmem119  k12_EL27.V11       Dek
# 4    k10_VL71.V5    mt-Co2    k12_BL4.V1     H2-D1   k12_YM47.V1     Slfn9
# 5   k12_EL29.V10    mt-Nd2    k10_D24.V3      Gpx1   k12_YM42.V8     Atad2
# 6   k12_AL51.V11    mt-Nd1  k12_AL38.V10     Calm1   k12_VL71.V6     Hspd1
# 7     k8_EL29.V2   mt-Cytb   k10_BL8.V10    Lgals1   k12_D44.V12    Rps3a1
# 8     k8_EL27.V5    mt-Nd4    k10_D44.V6      Ftl1   k12_EL29.V4     Rplp1
# 9     k8_AL51.V8   Gm42418    k12_BL8.V2   mt-Cytb   k10_AL51.V8      Lig1
# 10   k10_EL29.V1     Ahnak     k8_D44.V4      Fth1   k10_YM42.V1      Tpt1
# 11   k10_AL51.V1       Ncl    k12_D44.V8    Cyb5r3    k8_OX66.V6       Ncl
# 12   k10_EL28.V7    mt-Nd5    k10_BL4.V1     Pdia3    k12_D65.V1    Eef1a1
# 13  k12_EL28.V10     Neat1   k10_AL32.V6    Igfbp6    k8_YM42.V5      Rpsa
# 14   k10_VL12.V3      Rbpj    k8_BL12.V6      Cd81          None  Hsp90ab1
# 15   k12_EL27.V3     Eif3a          None    Tmsb4x          None     Stmn1
# 16   k12_VL11.V7    Hnrnpu          None      Tspo          None      Npm1
# 17   k12_YM47.V7  Hsp90ab1          None      Cd63          None       Ran
# 18   k10_NE33.V2   Slc38a2          None      Cav1          None     Rpl41
# 19    k8_VL71.V1    Prrc2c          None       Pkm          None      Ppia
# 20          None    Atp2b1          None    Lgals3          None       Set
# 21          None     Rps15          None     H2-K1          None      Rps8
# 22          None      Tpt1          None     Anxa5          None    Nap1l1
# 23          None     Hmga2          None     Prdx1          None       Dut
# 24          None     Itgb1          None       B2m          None     Rps12
# 25          None      Calu          None    Ifitm3          None     Rpl13
# 26          None    Rpl23a          None       Mt1          None    Ranbp1
# 27          None       Tpr          None    Lgals7          None      Rpl8
# 28          None    Spata7          None      Cstb          None     Rps4x
# 29          None    Pabpc1          None    Pcolce          None      Rps5
# 30          None     Rock2          None    S100a6          None     Rps10
# 31          None    mt-Nd3          None   Tinagl1          None      Ybx1
# 32          None    Serbp1          None    Cavin2          None      Rpl7
# 33          None   Ankrd11          None     Traf5          None     Rpl30
# 34          None      Plec          None    mt-Nd1          None     Rps29
# 35          None     Cald1          None   Selenof          None     Rplp0
# 36          None     Hspd1          None  Tmem176b          None     Rpl32
# 37          None     Rpl12          None  Ftl1-ps1          None      Fth1
# 38          None   Zfp36l2          None     Lamp1          None    S100a4
# 39          None     Rps17          None     Rpl41          None      Mcm6
# 40          None    Sptbn1          None     Rpl32          None      Actb
# 41          None       Set          None     Anxa2          None     Rps24
# 42          None    Scaf11          None     Mgst3          None     Rps16
# 43          None      Ptma          None   Hsd17b4          None     Rpl12
# 44          None    Nap1l1          None      Lrp1          None    S100a6
# 45          None     Hspa5          None      Ly6e          None     Tubb5
# 46          None    Iqgap1          None   Gm10260          None    Lgals1
# 47          None   Hsp90b1          None  Tmem176a          None    Serbp1
# 48          None   Hnrnpa3          None      Actb          None  Hsp90aa1
# 49          None     Eif3c          None     Clic1          None    Rps15a
#
#        MP11 (11) MP12_Gene    MP12 (11)
# 0     k10_BL8.V4       Dcn  k12_NE31.V8
# 1     k10_BL8.V4      Fth1  k12_NE31.V8
# 2     k10_D44.V2       Ogn  k12_BL12.V3
# 3     k12_BL8.V5     Itm2b   k8_BL12.V5
# 4   k12_AL32.V12     Cebpd   k10_BL8.V2
# 5      k8_BL8.V6      Apod   k12_BL8.V6
# 6      k8_D44.V8      Cst3    k8_BL8.V5
# 7     k10_BL8.V1    Ifitm1  k10_AL32.V5
# 8     k8_AL32.V4      Spp1   k8_NE33.V5
# 9     k12_BL4.V8      Aspn  k10_YM12.V6
# 10   k12_BL12.V8    Ifitm3   k8_NE31.V8
# 11    k12_BL8.V3  Tmem176b  k10_OX71.V7
# 12          None     Cebpb         None
# 13          None      C1s1         None
# 14          None       Mgp         None
# 15          None      Cd63         None
# 16          None     H2-D1         None
# 17          None       B2m         None
# 18          None       Fn1         None
# 19          None       Ubb         None
# 20          None  Tmem176a         None
# 21          None      Tpt1         None
# 22          None      Lrp1         None
# 23          None        Cp         None
# 24          None     Rpl10         None
# 25          None    Igfbp4         None
# 26          None      Rpl9         None
# 27          None    S100a6         None
# 28          None      Ctsl         None
# 29          None    Rps3a1         None
# 30          None      Rps9         None
# 31          None     Rplp1         None
# 32          None     Pfdn5         None
# 33          None     Rps27         None
# 34          None    Tmsb4x         None
# 35          None    Pcolce         None
# 36          None     Plac8         None
# 37          None      Rpl7         None
# 38          None   mt-Cytb         None
# 39          None     Rpl30         None
# 40          None  Baiap2l1         None
# 41          None     Rps4x         None
# 42          None   Rarres2         None
# 43          None    Rabac1         None
# 44          None   Laptm4a         None
# 45          None     H2-K1         None
# 46          None     Rps23         None
# 47          None   Selenop         None
# 48          None      Eif1         None
# 49          None     Rpl39         None
#
# [50 rows x 24 columns]
