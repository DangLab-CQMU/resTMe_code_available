# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from multiprocessing import Pool
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor
import scipy.stats as ss
import re
import sys
sys.path.append("/home/ziryu_wang/.conda/envs/py36_cmap/lib/python3.6/site-packages")
#sys.path
from cmapPy.pandasGEXpress.parse import parse
import cmapPy.pandasGEXpress.subset_gctoo as sg

# %%
cp = parse("/home/ziryu_wang/database/cMAP/level5_beta_trt_cp_n720216x12328.gctx")
compoundinfo = pd.read_csv('/home/ziryu_wang/database/cMAP/compoundinfo_beta.txt',sep = '\t')
sigInfo = pd.read_csv('/home/ziryu_wang/database/cMAP/siginfo_beta.txt',sep='\t')
geneinfo = pd.read_csv('/home/ziryu_wang/database/cMAP/geneinfo_beta.txt', sep = '\t')
Celine = pd.read_csv('/home/ziryu_wang/database/cMAP/cellinfo_beta.txt',sep = '\t')
# Mapping TCGA acronyms to the dataset's primary disease entries
tcga_mapping = {
    "BLCA": "bladder cancer",
    "BRCA": "breast cancer",
    "COAD": "colon cancer",
    "HNSC": "head and neck cancer",
    "KIRC": "kidney cancer",
    "LIHC": "liver cancer",
    "LUAD": "lung cancer",
    "PRAD": "prostate cancer"
}

# Creating a DataFrame with this mapping
df_mapping = pd.DataFrame(list(tcga_mapping.items()), columns=['TCGA_Acronym', 'Primary_Disease'])

print(df_mapping)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (0,3,4,28,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   TCGA_Acronym       Primary_Disease
# 0         BLCA        bladder cancer
# 1         BRCA         breast cancer
# 2         COAD          colon cancer
# 3         HNSC  head and neck cancer
# 4         KIRC         kidney cancer
# 5         LIHC          liver cancer
# 6         LUAD           lung cancer
# 7         PRAD       prostate cancer

# %%
def process_data(cancertype):
    """
    Processes individual cancer type data by reading and transforming it.
    Returns transformed TCGA and immuAI dataframes for a given cancer type.
    """    
    
    tcga_path = f'/home/ziryu_wang/code_ava/Required_files/TCGA-{cancertype}_alldiff.csv'
    immuAI_path = f'/home/ziryu_wang/code_ava/Required_files/immuAI_{cancertype}.txt'

    # Read and process the TCGA data
    tcga = pd.read_csv(tcga_path, index_col=0)
    tcga = (tcga.iloc[:, 4:len(tcga.columns)-2]).T
    print(f'{cancertype} TCGA {tcga.shape[0]}')

    # Read the immuAI data
    immuAI = pd.read_csv(immuAI_path, sep='\t')

    return tcga, immuAI

def main():
    # Assume df_mapping is preloaded
    cancertypes = df_mapping['TCGA_Acronym']

    with Pool(processes=8) as pool:
        results = pool.map(process_data, cancertypes)

    # Unpack the results and concatenate all the dataframes
    all_merged_tcga, all_merged_immuAI = zip(*results)
    final_tcga = pd.concat(all_merged_tcga)
    final_immuAI = pd.concat(all_merged_immuAI)

    # Print the total number of samples processed
    print(f'All TCGA sample: {final_tcga.shape[0]}')
    print(f'All immuAI sample: {final_immuAI.shape[0]}')
    #final_tcga.to_csv('/home/ziryu_wang/code_ava/step3-cmapPy4_DurgIdent/output/final_tcga.csv')
    #final_immuAI.to_csv('/home/ziryu_wang/code_ava/step3-cmapPy4_DurgIdent/output/final_immuAI.csv')
    return final_tcga, final_immuAI


if __name__ == '__main__':
    final_tcga, final_immuAI = main()
    #final_tcga = pd.read_csv('/home/ziryu_wang/code_ava/step3-cmapPy4_DurgIdent/output/final_tcga.csv')
    #final_immuAI = pd.read_csv('/home/ziryu_wang/code_ava/step3-cmapPy4_DurgIdent/output/final_immuAI.csv')
# Out:
# LIHC TCGA 424
# BLCA TCGA 433
# COAD TCGA 521
# LUAD TCGA 594
# KIRC TCGA 611
# PRAD TCGA 551
# HNSC TCGA 546
# BRCA TCGA 1222
# All TCGA sample: 4902
# All immuAI sample: 4696

# %%
## low dose
sel_compound = pd.read_csv(f'/home/ziryu_wang/code_ava/Required_files/drugCom54.csv',index_col=0)
sel_compound = sel_compound.T
sel_compound_filt = sel_compound.index
# Replacing non-zero values with column names
for column in sel_compound.columns:
    sel_compound[column] = sel_compound[column].apply(lambda x: column if x != 0 else 0)

# Initialize a list to store each DataFrame for genes
drug_stats = []

# Initialize a list to store each DataFrame
all_merged_dfs = []

# Iterate over each drug and print the corresponding cancer types
for drug in sel_compound_filt:
    cancertype = sel_compound.loc[drug, sel_compound.loc[drug] != 0].tolist()
    #celltype = df_mapping['Primary_Disease'].tolist()
    celltype = df_mapping[df_mapping['TCGA_Acronym'].isin(cancertype)]['Primary_Disease'].tolist()
    print(f"Drug: {drug}, celltype: {celltype}")
    coloncl = Celine[Celine['primary_disease'].isin(celltype)]
    my_col_metadata = parse("/home/ziryu_wang/database/cMAP/level5_beta_trt_cp_n720216x12328.gctx", col_meta_only=True)
    sigInfo1 = sigInfo[sigInfo['sig_id'].isin(my_col_metadata.index.values)]
    sigInfo1 = sigInfo1[(sigInfo1['pert_dose'] < sigInfo['pert_dose'].median()) & (sigInfo1['pert_time'] < 48.0)]#low dose
    colon_tab = sigInfo1[sigInfo1["cell_iname"].isin(coloncl["cell_iname"])]
    colon_ids = sigInfo1['sig_id'][sigInfo1['cmap_name'].isin([drug])]
    print(f'{len(colon_ids)} ids were found from {drug}.')

    mito_gctoo = parse("/home/ziryu_wang/database/cMAP/level5_beta_trt_cp_n720216x12328.gctx", cid=colon_ids)
    mito_gctoo.data_df.mask((mito_gctoo.data_df > -1.645) & (mito_gctoo.data_df < 1.645), np.nan, inplace=True)
    
    # Quantile calculation
    quantiles = mito_gctoo.data_df.quantile([0.33, 0.67], axis=1)
    max_quantile = quantiles.apply(lambda x: x[0.67] if abs(x[0.67]) > abs(x[0.33]) else x[0.33], axis=0)
    print(max_quantile)

    # Normalized using the greatest quantile
    normalized_df = (mito_gctoo.data_df - max_quantile.min()) / (max_quantile.max() - max_quantile.min())
    normalized_df = normalized_df.clip(lower=0, upper=1)  # Limit the value to between 0 and 1
    print(normalized_df)

    # Calculate the standardized mean score for each gene
    gene_normalized_scores = pd.DataFrame(normalized_df.mean(axis=1), columns=['normalized_score'])
    gene_normalized_scores['max_quantile']=max_quantile
    gene_normalized_scores['gene_id'] = gene_normalized_scores.index
    gene_normalized_scores['gene_id'] = gene_normalized_scores['gene_id'].astype(int)
    print(gene_normalized_scores)

    # Merge data
    gene_M = geneinfo[geneinfo['gene_id'].isin(gene_normalized_scores.index)]
    merged_df = pd.merge(gene_normalized_scores, gene_M, on='gene_id')
    merged_df['Drug'] = drug  # 添加药物列
    merged_df_fil = merged_df[(merged_df["max_quantile"] <= -3.891) | (merged_df["max_quantile"] >= 3.891)]#99.99% zscore
    all_merged_dfs.append(merged_df_fil)
    print(f'================================== {merged_df_fil.shape[0]} genes were found from {drug}.')
    
    # Append drug statistics
    drug_stats.append([drug, len(colon_ids), merged_df_fil.shape[0]])

# Concatenate all DataFrames into a single DataFrame
final_df = pd.concat(all_merged_dfs)
final_df.to_csv('/home/ziryu_wang/code_ava/step3-cmapPy4_DurgIdent/output/drug54ToGene.csv')

# Create and save statistics DataFrame
stats_df = pd.DataFrame(drug_stats, columns=['drug', 'number of pert_id', 'number of pert_genes'])
print(stats_df)
stats_df.to_csv('/home/ziryu_wang/code_ava/step3-cmapPy4_DurgIdent/output/drugStats-l.csv', index=False)
# Out:
# Drug: daunorubicin, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 393 ids were found from daunorubicin.
# ================================== 276 genes were found from daunorubicin.
# Drug: alvocidib, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 490 ids were found from alvocidib.
# ================================== 2254 genes were found from alvocidib.
# Drug: mitoxantrone, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 975 ids were found from mitoxantrone.
# ================================== 289 genes were found from mitoxantrone.
# Drug: epirubicin, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 288 ids were found from epirubicin.
# ================================== 440 genes were found from epirubicin.
# Drug: idarubicin, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 298 ids were found from idarubicin.
# ================================== 1064 genes were found from idarubicin.
# Drug: JNJ-7706621, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'lung cancer', 'prostate cancer']
# 179 ids were found from JNJ-7706621.
# ================================== 38 genes were found from JNJ-7706621.
# Drug: bortezomib, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'liver cancer', 'lung cancer']
# 494 ids were found from bortezomib.
# ================================== 1130 genes were found from bortezomib.
# Drug: panobinostat, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'lung cancer', 'prostate cancer']
# 361 ids were found from panobinostat.
# ================================== 826 genes were found from panobinostat.
# Drug: MG-132, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'lung cancer']
# 134 ids were found from MG-132.
# ================================== 119 genes were found from MG-132.
# Drug: YM-155, celltype: ['bladder cancer', 'breast cancer', 'head and neck cancer', 'kidney cancer', 'lung cancer']
# 390 ids were found from YM-155.
# ================================== 1029 genes were found from YM-155.
# Drug: doxorubicin, celltype: ['breast cancer', 'colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 416 ids were found from doxorubicin.
# ================================== 278 genes were found from doxorubicin.
# Drug: TP-0903, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 17 ids were found from TP-0903.
# ================================== 6707 genes were found from TP-0903.
# Drug: PF-562271, celltype: ['bladder cancer', 'breast cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 278 ids were found from PF-562271.
# ================================== 134 genes were found from PF-562271.
# Drug: PHA-793887, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'lung cancer', 'prostate cancer']
# 467 ids were found from PHA-793887.
# ================================== 40 genes were found from PHA-793887.
# Drug: BRD-A19037878, celltype: ['breast cancer', 'colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 544 ids were found from BRD-A19037878.
# ================================== 332 genes were found from BRD-A19037878.
# Drug: ponatinib, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'lung cancer']
# 328 ids were found from ponatinib.
# ================================== 20 genes were found from ponatinib.
# Drug: withaferin-a, celltype: ['breast cancer', 'colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 414 ids were found from withaferin-a.
# ================================== 98 genes were found from withaferin-a.
# Drug: dinaciclib, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 309 ids were found from dinaciclib.
# ================================== 4482 genes were found from dinaciclib.
# Drug: BRD-K76674262, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'lung cancer']
# 337 ids were found from BRD-K76674262.
# ================================== 651 genes were found from BRD-K76674262.
# Drug: R-547, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 314 ids were found from R-547.
# ================================== 199 genes were found from R-547.
# Drug: BMS-387032, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 204 ids were found from BMS-387032.
# ================================== 247 genes were found from BMS-387032.
# Drug: WZ-3105, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 107 ids were found from WZ-3105.
# ================================== 841 genes were found from WZ-3105.
# Drug: A-443654, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 221 ids were found from A-443654.
# ================================== 1413 genes were found from A-443654.
# Drug: PIK-75, celltype: ['colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 126 ids were found from PIK-75.
# ================================== 2868 genes were found from PIK-75.
# Drug: triptolide, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 238 ids were found from triptolide.
# ================================== 2247 genes were found from triptolide.
# Drug: camptothecin, celltype: ['bladder cancer', 'breast cancer', 'lung cancer', 'prostate cancer']
# 383 ids were found from camptothecin.
# ================================== 205 genes were found from camptothecin.
# Drug: CGP-60474, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 439 ids were found from CGP-60474.
# ================================== 3214 genes were found from CGP-60474.
# Drug: alsterpaullone, celltype: ['colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 34 ids were found from alsterpaullone.
# ================================== 119 genes were found from alsterpaullone.
# Drug: ceritinib, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'lung cancer']
# 175 ids were found from ceritinib.
# ================================== 1331 genes were found from ceritinib.
# Drug: OTS-167, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 203 ids were found from OTS-167.
# ================================== 3283 genes were found from OTS-167.
# Drug: celastrol, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 125 ids were found from celastrol.
# ================================== 106 genes were found from celastrol.
# Drug: LDN-193189, celltype: ['breast cancer', 'colon cancer', 'lung cancer']
# 197 ids were found from LDN-193189.
# ================================== 36 genes were found from LDN-193189.
# Drug: CGS-15943, celltype: ['breast cancer', 'colon cancer', 'lung cancer']
# 184 ids were found from CGS-15943.
# ================================== 83 genes were found from CGS-15943.
# Drug: RITA, celltype: ['breast cancer', 'colon cancer', 'liver cancer']
# 207 ids were found from RITA.
# ================================== 104 genes were found from RITA.
# Drug: pacritinib, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 16 ids were found from pacritinib.
# ================================== 139 genes were found from pacritinib.
# Drug: defactinib, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 164 ids were found from defactinib.
# ================================== 153 genes were found from defactinib.
# Drug: ABT-737, celltype: ['kidney cancer', 'lung cancer', 'prostate cancer']
# 462 ids were found from ABT-737.
# ================================== 127 genes were found from ABT-737.
# Drug: CHIR-124, celltype: ['bladder cancer', 'liver cancer', 'lung cancer']
# 21 ids were found from CHIR-124.
# ================================== 184 genes were found from CHIR-124.
# Drug: staurosporine, celltype: ['colon cancer', 'lung cancer', 'prostate cancer']
# 45 ids were found from staurosporine.
# ================================== 1003 genes were found from staurosporine.
# Drug: nepafenac, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 158 ids were found from nepafenac.
# ================================== 260 genes were found from nepafenac.
# Drug: oxypurinol, celltype: ['breast cancer', 'colon cancer', 'lung cancer']
# 174 ids were found from oxypurinol.
# ================================== 206 genes were found from oxypurinol.
# Drug: tizanidine, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 132 ids were found from tizanidine.
# ================================== 2657 genes were found from tizanidine.
# Drug: wortmannin, celltype: ['breast cancer', 'colon cancer', 'prostate cancer']
# 691 ids were found from wortmannin.
# ================================== 32 genes were found from wortmannin.
# Drug: AZD-5438, celltype: ['colon cancer', 'lung cancer', 'prostate cancer']
# 372 ids were found from AZD-5438.
# ================================== 71 genes were found from AZD-5438.
# Drug: BRD-A36275421, celltype: ['colon cancer', 'lung cancer', 'prostate cancer']
# 105 ids were found from BRD-A36275421.
# ================================== 2281 genes were found from BRD-A36275421.
# Drug: anguidine, celltype: ['colon cancer', 'head and neck cancer', 'lung cancer']
# 155 ids were found from anguidine.
# ================================== 1644 genes were found from anguidine.
# Drug: BRD-K98645985, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 32 ids were found from BRD-K98645985.
# ================================== 133 genes were found from BRD-K98645985.
# Drug: API-001, celltype: ['bladder cancer', 'colon cancer', 'lung cancer']
# 157 ids were found from API-001.
# ================================== 187 genes were found from API-001.
# Drug: AT-7519, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 277 ids were found from AT-7519.
# ================================== 185 genes were found from AT-7519.
# Drug: mitomycin-c, celltype: ['bladder cancer', 'liver cancer', 'lung cancer']
# 306 ids were found from mitomycin-c.
# ================================== 46 genes were found from mitomycin-c.
# Drug: digoxin, celltype: ['bladder cancer', 'head and neck cancer', 'lung cancer']
# 284 ids were found from digoxin.
# ================================== 375 genes were found from digoxin.
# Drug: AS-601245, celltype: ['breast cancer', 'colon cancer', 'lung cancer']
# 126 ids were found from AS-601245.
# ================================== 583 genes were found from AS-601245.
# Drug: BIX-01294, celltype: ['breast cancer', 'liver cancer', 'lung cancer']
# 198 ids were found from BIX-01294.
# ================================== 188 genes were found from BIX-01294.
# Drug: tacrine, celltype: ['bladder cancer', 'colon cancer', 'lung cancer']
# 157 ids were found from tacrine.
# ================================== 320 genes were found from tacrine.
#               drug  number of pert_id  number of pert_genes
# 0     daunorubicin                393                   276
# 1        alvocidib                490                  2254
# 2     mitoxantrone                975                   289
# 3       epirubicin                288                   440
# 4       idarubicin                298                  1064
# 5      JNJ-7706621                179                    38
# 6       bortezomib                494                  1130
# 7     panobinostat                361                   826
# 8           MG-132                134                   119
# 9           YM-155                390                  1029
# 10     doxorubicin                416                   278
# 11         TP-0903                 17                  6707
# 12       PF-562271                278                   134
# 13      PHA-793887                467                    40
# 14   BRD-A19037878                544                   332
# 15       ponatinib                328                    20
# 16    withaferin-a                414                    98
# 17      dinaciclib                309                  4482
# 18   BRD-K76674262                337                   651
# 19           R-547                314                   199
# 20      BMS-387032                204                   247
# 21         WZ-3105                107                   841
# 22        A-443654                221                  1413
# 23          PIK-75                126                  2868
# 24      triptolide                238                  2247
# 25    camptothecin                383                   205
# 26       CGP-60474                439                  3214
# 27  alsterpaullone                 34                   119
# 28       ceritinib                175                  1331
# 29         OTS-167                203                  3283
# 30       celastrol                125                   106
# 31      LDN-193189                197                    36
# 32       CGS-15943                184                    83
# 33            RITA                207                   104
# 34      pacritinib                 16                   139
# 35      defactinib                164                   153
# 36         ABT-737                462                   127
# 37        CHIR-124                 21                   184
# 38   staurosporine                 45                  1003
# 39       nepafenac                158                   260
# 40      oxypurinol                174                   206
# 41      tizanidine                132                  2657
# 42      wortmannin                691                    32
# 43        AZD-5438                372                    71
# 44   BRD-A36275421                105                  2281
# 45       anguidine                155                  1644
# 46   BRD-K98645985                 32                   133
# 47         API-001                157                   187
# 48         AT-7519                277                   185
# 49     mitomycin-c                306                    46
# 50         digoxin                284                   375
# 51       AS-601245                126                   583
# 52       BIX-01294                198                   188
# 53         tacrine                157                   320

# %%
##  high dose
sel_compound = pd.read_csv(f'/home/ziryu_wang/code_ava/Required_files/drugCom54.csv',index_col=0)
sel_compound = sel_compound.T
sel_compound_filt = sel_compound.index
# Replacing non-zero values with column names
for column in sel_compound.columns:
    sel_compound[column] = sel_compound[column].apply(lambda x: column if x != 0 else 0)

# Initialize a list to store each DataFrame for genes
drug_stats = []

# Initialize a list to store each DataFrame
all_merged_dfs = []

# Iterate over each drug and print the corresponding cancer types
for drug in sel_compound_filt:
    cancertype = sel_compound.loc[drug, sel_compound.loc[drug] != 0].tolist()
    #celltype = df_mapping['Primary_Disease'].tolist()
    celltype = df_mapping[df_mapping['TCGA_Acronym'].isin(cancertype)]['Primary_Disease'].tolist()
    print(f"Drug: {drug}, celltype: {celltype}")
    coloncl = Celine[Celine['primary_disease'].isin(celltype)]
    my_col_metadata = parse("/home/ziryu_wang/database/cMAP/level5_beta_trt_cp_n720216x12328.gctx", col_meta_only=True)
    sigInfo1 = sigInfo[sigInfo['sig_id'].isin(my_col_metadata.index.values)]
    sigInfo1 = sigInfo1[(sigInfo1['pert_dose'] > sigInfo['pert_dose'].median()) & (sigInfo1['pert_time'] >= 24)]#high dose
    colon_tab = sigInfo1[sigInfo1["cell_iname"].isin(coloncl["cell_iname"])]
    colon_ids = sigInfo1['sig_id'][sigInfo1['cmap_name'].isin([drug])]
    print(f'{len(colon_ids)} ids were found from {drug}.')

    mito_gctoo = parse("/home/ziryu_wang/database/cMAP/level5_beta_trt_cp_n720216x12328.gctx", cid=colon_ids)
    mito_gctoo.data_df.mask((mito_gctoo.data_df > -1.645) & (mito_gctoo.data_df < 1.645), np.nan, inplace=True)
    
    # Quantile calculation
    quantiles = mito_gctoo.data_df.quantile([0.33, 0.67], axis=1)
    max_quantile = quantiles.apply(lambda x: x[0.67] if abs(x[0.67]) > abs(x[0.33]) else x[0.33], axis=0)
    print(max_quantile)

    # Normalized using the greatest quantile
    normalized_df = (mito_gctoo.data_df - max_quantile.min()) / (max_quantile.max() - max_quantile.min())
    normalized_df = normalized_df.clip(lower=0, upper=1)  # Limit the value to between 0 and 1
    print(normalized_df)

    # Calculate the standardized mean score for each gene
    gene_normalized_scores = pd.DataFrame(normalized_df.mean(axis=1), columns=['normalized_score'])
    gene_normalized_scores['max_quantile']=max_quantile
    gene_normalized_scores['gene_id'] = gene_normalized_scores.index
    gene_normalized_scores['gene_id'] = gene_normalized_scores['gene_id'].astype(int)
    print(gene_normalized_scores)

    # Merge data
    gene_M = geneinfo[geneinfo['gene_id'].isin(gene_normalized_scores.index)]
    merged_df = pd.merge(gene_normalized_scores, gene_M, on='gene_id')
    merged_df['Drug'] = drug  # 添加药物列
    merged_df_fil = merged_df[(merged_df["max_quantile"] <= -3.891) | (merged_df["max_quantile"] >= 3.891)]#99.99% zscore
    all_merged_dfs.append(merged_df_fil)
    print(f'================================== {merged_df_fil.shape[0]} genes were found from {drug}.')
    
    # Append drug statistics
    drug_stats.append([drug, len(colon_ids), merged_df_fil.shape[0]])

# Concatenate all DataFrames into a single DataFrame
final_df = pd.concat(all_merged_dfs)
final_df.to_csv('/home/ziryu_wang/code_ava/step3-cmapPy4_DurgIdent/output/drug54ToGene-h.csv')

# Create and save statistics DataFrame
stats_df = pd.DataFrame(drug_stats, columns=['drug', 'number of pert_id', 'number of pert_genes'])
print(stats_df)
stats_df.to_csv('/home/ziryu_wang/code_ava/step3-cmapPy4_DurgIdent/output/drugStats-h.csv', index=False)
# Out:
# Drug: daunorubicin, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 159 ids were found from daunorubicin.
# ================================== 4641 genes were found from daunorubicin.
# Drug: alvocidib, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 201 ids were found from alvocidib.
# ================================== 4404 genes were found from alvocidib.
# Drug: mitoxantrone, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 628 ids were found from mitoxantrone.
# ================================== 1909 genes were found from mitoxantrone.
# Drug: epirubicin, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 111 ids were found from epirubicin.
# ================================== 4931 genes were found from epirubicin.
# Drug: idarubicin, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 61 ids were found from idarubicin.
# ================================== 5669 genes were found from idarubicin.
# Drug: JNJ-7706621, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'lung cancer', 'prostate cancer']
# 101 ids were found from JNJ-7706621.
# ================================== 3386 genes were found from JNJ-7706621.
# Drug: bortezomib, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'liver cancer', 'lung cancer']
# 7863 ids were found from bortezomib.
# ================================== 755 genes were found from bortezomib.
# Drug: panobinostat, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'lung cancer', 'prostate cancer']
# 202 ids were found from panobinostat.
# ================================== 906 genes were found from panobinostat.
# Drug: MG-132, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'kidney cancer', 'lung cancer']
# 7967 ids were found from MG-132.
# ================================== 729 genes were found from MG-132.
# Drug: YM-155, celltype: ['bladder cancer', 'breast cancer', 'head and neck cancer', 'kidney cancer', 'lung cancer']
# 92 ids were found from YM-155.
# ================================== 3988 genes were found from YM-155.
# Drug: doxorubicin, celltype: ['breast cancer', 'colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 137 ids were found from doxorubicin.
# ================================== 2229 genes were found from doxorubicin.
# Drug: TP-0903, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 21 ids were found from TP-0903.
# ================================== 6579 genes were found from TP-0903.
# Drug: PF-562271, celltype: ['bladder cancer', 'breast cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 112 ids were found from PF-562271.
# ================================== 1882 genes were found from PF-562271.
# Drug: PHA-793887, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'lung cancer', 'prostate cancer']
# 183 ids were found from PHA-793887.
# ================================== 4100 genes were found from PHA-793887.
# Drug: BRD-A19037878, celltype: ['breast cancer', 'colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 591 ids were found from BRD-A19037878.
# ================================== 675 genes were found from BRD-A19037878.
# Drug: ponatinib, celltype: ['bladder cancer', 'breast cancer', 'colon cancer', 'head and neck cancer', 'lung cancer']
# 120 ids were found from ponatinib.
# ================================== 4160 genes were found from ponatinib.
# Drug: withaferin-a, celltype: ['breast cancer', 'colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 395 ids were found from withaferin-a.
# ================================== 1177 genes were found from withaferin-a.
# Drug: dinaciclib, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 88 ids were found from dinaciclib.
# ================================== 4617 genes were found from dinaciclib.
# Drug: BRD-K76674262, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'lung cancer']
# 102 ids were found from BRD-K76674262.
# ================================== 3649 genes were found from BRD-K76674262.
# Drug: R-547, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 105 ids were found from R-547.
# ================================== 5496 genes were found from R-547.
# Drug: BMS-387032, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 81 ids were found from BMS-387032.
# ================================== 3863 genes were found from BMS-387032.
# Drug: WZ-3105, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 26 ids were found from WZ-3105.
# ================================== 3700 genes were found from WZ-3105.
# Drug: A-443654, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 41 ids were found from A-443654.
# ================================== 4846 genes were found from A-443654.
# Drug: PIK-75, celltype: ['colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 29 ids were found from PIK-75.
# ================================== 3828 genes were found from PIK-75.
# Drug: triptolide, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 32 ids were found from triptolide.
# ================================== 3276 genes were found from triptolide.
# Drug: camptothecin, celltype: ['bladder cancer', 'breast cancer', 'lung cancer', 'prostate cancer']
# 158 ids were found from camptothecin.
# ================================== 845 genes were found from camptothecin.
# Drug: CGP-60474, celltype: ['breast cancer', 'colon cancer', 'lung cancer', 'prostate cancer']
# 173 ids were found from CGP-60474.
# ================================== 3553 genes were found from CGP-60474.
# Drug: alsterpaullone, celltype: ['colon cancer', 'liver cancer', 'lung cancer', 'prostate cancer']
# 19 ids were found from alsterpaullone.
# ================================== 3595 genes were found from alsterpaullone.
# Drug: ceritinib, celltype: ['breast cancer', 'colon cancer', 'head and neck cancer', 'lung cancer']
# 32 ids were found from ceritinib.
# ================================== 6792 genes were found from ceritinib.
# Drug: OTS-167, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 62 ids were found from OTS-167.
# ================================== 4653 genes were found from OTS-167.
# Drug: celastrol, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 40 ids were found from celastrol.
# ================================== 2361 genes were found from celastrol.
# Drug: LDN-193189, celltype: ['breast cancer', 'colon cancer', 'lung cancer']
# 66 ids were found from LDN-193189.
# ================================== 2176 genes were found from LDN-193189.
# Drug: CGS-15943, celltype: ['breast cancer', 'colon cancer', 'lung cancer']
# 127 ids were found from CGS-15943.
# ================================== 177 genes were found from CGS-15943.
# Drug: RITA, celltype: ['breast cancer', 'colon cancer', 'liver cancer']
# 148 ids were found from RITA.
# ================================== 317 genes were found from RITA.
# Drug: pacritinib, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 13 ids were found from pacritinib.
# ================================== 5799 genes were found from pacritinib.
# Drug: defactinib, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 74 ids were found from defactinib.
# ================================== 743 genes were found from defactinib.
# Drug: ABT-737, celltype: ['kidney cancer', 'lung cancer', 'prostate cancer']
# 206 ids were found from ABT-737.
# ================================== 101 genes were found from ABT-737.
# Drug: CHIR-124, celltype: ['bladder cancer', 'liver cancer', 'lung cancer']
# 26 ids were found from CHIR-124.
# ================================== 4535 genes were found from CHIR-124.
# Drug: staurosporine, celltype: ['colon cancer', 'lung cancer', 'prostate cancer']
# 28 ids were found from staurosporine.
# ================================== 2614 genes were found from staurosporine.
# Drug: nepafenac, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 74 ids were found from nepafenac.
# ================================== 200 genes were found from nepafenac.
# Drug: oxypurinol, celltype: ['breast cancer', 'colon cancer', 'lung cancer']
# 92 ids were found from oxypurinol.
# ================================== 3484 genes were found from oxypurinol.
# Drug: tizanidine, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 34 ids were found from tizanidine.
# ================================== 129 genes were found from tizanidine.
# Drug: wortmannin, celltype: ['breast cancer', 'colon cancer', 'prostate cancer']
# 600 ids were found from wortmannin.
# ================================== 48 genes were found from wortmannin.
# Drug: AZD-5438, celltype: ['colon cancer', 'lung cancer', 'prostate cancer']
# 77 ids were found from AZD-5438.
# ================================== 2854 genes were found from AZD-5438.
# Drug: BRD-A36275421, celltype: ['colon cancer', 'lung cancer', 'prostate cancer']
# 41 ids were found from BRD-A36275421.
# ================================== 913 genes were found from BRD-A36275421.
# Drug: anguidine, celltype: ['colon cancer', 'head and neck cancer', 'lung cancer']
# 53 ids were found from anguidine.
# ================================== 3931 genes were found from anguidine.
# Drug: BRD-K98645985, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 36 ids were found from BRD-K98645985.
# ================================== 2608 genes were found from BRD-K98645985.
# Drug: API-001, celltype: ['bladder cancer', 'colon cancer', 'lung cancer']
# 76 ids were found from API-001.
# ================================== 1322 genes were found from API-001.
# Drug: AT-7519, celltype: ['breast cancer', 'lung cancer', 'prostate cancer']
# 86 ids were found from AT-7519.
# ================================== 3526 genes were found from AT-7519.
# Drug: mitomycin-c, celltype: ['bladder cancer', 'liver cancer', 'lung cancer']
# 124 ids were found from mitomycin-c.
# ================================== 653 genes were found from mitomycin-c.
# Drug: digoxin, celltype: ['bladder cancer', 'head and neck cancer', 'lung cancer']
# 137 ids were found from digoxin.
# ================================== 998 genes were found from digoxin.
# Drug: AS-601245, celltype: ['breast cancer', 'colon cancer', 'lung cancer']
# 48 ids were found from AS-601245.
# ================================== 843 genes were found from AS-601245.
# Drug: BIX-01294, celltype: ['breast cancer', 'liver cancer', 'lung cancer']
# 123 ids were found from BIX-01294.
# ================================== 2123 genes were found from BIX-01294.
# Drug: tacrine, celltype: ['bladder cancer', 'colon cancer', 'lung cancer']
# 94 ids were found from tacrine.
# ================================== 574 genes were found from tacrine.
#               drug  number of pert_id  number of pert_genes
# 0     daunorubicin                159                  4641
# 1        alvocidib                201                  4404
# 2     mitoxantrone                628                  1909
# 3       epirubicin                111                  4931
# 4       idarubicin                 61                  5669
# 5      JNJ-7706621                101                  3386
# 6       bortezomib               7863                   755
# 7     panobinostat                202                   906
# 8           MG-132               7967                   729
# 9           YM-155                 92                  3988
# 10     doxorubicin                137                  2229
# 11         TP-0903                 21                  6579
# 12       PF-562271                112                  1882
# 13      PHA-793887                183                  4100
# 14   BRD-A19037878                591                   675
# 15       ponatinib                120                  4160
# 16    withaferin-a                395                  1177
# 17      dinaciclib                 88                  4617
# 18   BRD-K76674262                102                  3649
# 19           R-547                105                  5496
# 20      BMS-387032                 81                  3863
# 21         WZ-3105                 26                  3700
# 22        A-443654                 41                  4846
# 23          PIK-75                 29                  3828
# 24      triptolide                 32                  3276
# 25    camptothecin                158                   845
# 26       CGP-60474                173                  3553
# 27  alsterpaullone                 19                  3595
# 28       ceritinib                 32                  6792
# 29         OTS-167                 62                  4653
# 30       celastrol                 40                  2361
# 31      LDN-193189                 66                  2176
# 32       CGS-15943                127                   177
# 33            RITA                148                   317
# 34      pacritinib                 13                  5799
# 35      defactinib                 74                   743
# 36         ABT-737                206                   101
# 37        CHIR-124                 26                  4535
# 38   staurosporine                 28                  2614
# 39       nepafenac                 74                   200
# 40      oxypurinol                 92                  3484
# 41      tizanidine                 34                   129
# 42      wortmannin                600                    48
# 43        AZD-5438                 77                  2854
# 44   BRD-A36275421                 41                   913
# 45       anguidine                 53                  3931
# 46   BRD-K98645985                 36                  2608
# 47         API-001                 76                  1322
# 48         AT-7519                 86                  3526
# 49     mitomycin-c                124                   653
# 50         digoxin                137                   998
# 51       AS-601245                 48                   843
# 52       BIX-01294                123                  2123
# 53         tacrine                 94                   574

# %%
## final
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor

    
def process_drug(drug, final_tcga, final_df, final_immuAI):
    # This function integrates the previously separated steps into one function per drug
    mixdata, df_sel = filter_and_merge_data(drug, final_tcga, final_df, final_immuAI)
    save_rho_pval = calculate_correlations(mixdata)
    cor = analyze_correlations(df_sel, save_rho_pval)
    drugimm1 = select_significant_correlations(cor)
    return drug, drugimm1

def filter_and_merge_data(drug, final_tcga, final_df, final_immuAI):
    print(drug)
    #print(f'Gene all: {final_tcga.shape[1]}')
    
    # Select genes based on the drug
    df_sel = final_df.loc[final_df['Drug'].isin([drug]),:]
    #print(f'==========df_sel {df_sel}')
    final_tcga_fil = final_tcga.loc[:, final_tcga.columns.isin(df_sel['ensembl_id'])]
    print(f'Gene selected by {drug}: {final_tcga_fil.shape[1]}')
    #print(f'==========final_tcga_fil {final_tcga_fil}')
    
    # Preparing data for merging
    final_tcga_fil['sample'] = final_tcga_fil.index
    final_immuAI.index = final_immuAI.index.str.replace('.','-')
    final_immuAI['sample'] = final_immuAI.index
    mixdata = pd.merge(final_immuAI, final_tcga_fil, on='sample')
    mixdata = mixdata[mixdata['sample'].str.contains('.*-0[1-9]A-')]
    mixdata = mixdata.drop(columns=['sample'])
    mixdata = mixdata.dropna(axis=1, how='any')
    
    return mixdata, df_sel

def calculate_correlations(mixdata):
    rho, pval = ss.spearmanr(mixdata)
    save_rho = pd.DataFrame(rho, columns=mixdata.columns, index=mixdata.columns)
    save_pval = pd.DataFrame(pval, columns=mixdata.columns, index=mixdata.columns)   
    #print(f'=========save_pval {drug} {save_pval}')   
    save_pval[save_pval >= 0.05] = np.nan
    save_pval[save_pval < 0.05] = 0
          
    save_rho_pval = save_rho.iloc[25:len(mixdata.columns), 0:25] + save_pval.iloc[25:len(mixdata.columns), 0:25]
    #print(f'==========len(save_rho_pval):{drug} {len(save_rho_pval)}')
    #print(f'{drug} {save_rho_pval}')
    return save_rho_pval

def analyze_correlations(df_sel, save_rho_pval):
    upG = df_sel.loc[df_sel['max_quantile'] >= 1.96, 'ensembl_id']
    downG = df_sel.loc[df_sel['max_quantile'] <= -1.96, 'ensembl_id']
    
    downGcor = -save_rho_pval[save_rho_pval.index.isin(downG)]
    upGcor = save_rho_pval[save_rho_pval.index.isin(upG)]
    cor = pd.concat([downGcor, upGcor])
    
    cor.loc["col_med"] = cor.apply(lambda x: x.median(), axis=0)
    cor.loc['gene_count'] = len(save_rho_pval) - cor.isna().sum()
    #print(f'==========len(cor):{drug} {len(cor)}')
    return cor

def select_significant_correlations(cor):
    drugimm = cor.loc[['col_med', 'gene_count']].T
    thre = 0.80*(len(cor)-2)
    #print(f'==========80% of selected genes contribute to the immune cell infiltrate (thre): {drug}, {thre}')
    drugimm['significant'] = drugimm.apply(lambda row: row['col_med'] if row['gene_count'] > thre else 0, axis=1)    
    print(drugimm)
    return drugimm['significant']

def main(sel_compound_filt, final_tcga, final_df, final_immuAI):
    results = {}
    with ThreadPoolExecutor(max_workers=16) as executor:
        future_to_drug = {executor.submit(process_drug, drug, final_tcga, final_df, final_immuAI): drug for drug in sel_compound_filt}
        for future in concurrent.futures.as_completed(future_to_drug):
            drug = future_to_drug[future]
            try:
                drug_name, drugimm1 = future.result()
                results[drug_name] = drugimm1
            except Exception as exc:
                print(f'{drug} generated an exception: {exc}')

    # Combine all results into a single DataFrame
    combined_results = pd.DataFrame(results)
    print(combined_results) 
    combined_results.to_csv('/home/ziryu_wang/code_ava/step3-cmapPy4_DurgIdent/output/DTC_combined_drugs-h.csv')

if __name__ == '__main__':
    main(sel_compound_filt, final_tcga, final_df, final_immuAI)
# Out:
# daunorubicin
# alvocidib
# mitoxantrone
# epirubicin
# idarubicin
# JNJ-7706621
# bortezomib
# panobinostat
# MG-132
# YM-155
# doxorubicin
# TP-0903
# PF-562271
# PHA-793887
# BRD-A19037878
# ponatinib
# Gene selected by YM-155: 3953
# <ipython-input-8-99815b7c30fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_tcga_fil['sample'] = final_tcga_fil.index
# Gene selected by PF-562271: 1865
# Gene selected by TP-0903: 6541
# Gene selected by alvocidib: 4373
# Gene selected by idarubicin: 5627Gene selected by JNJ-7706621: 3353
#
# Gene selected by ponatinib: 4127
# Gene selected by daunorubicin: 4604
# Gene selected by bortezomib: 755
# Gene selected by BRD-A19037878: 674
# Gene selected by doxorubicin: 2209
# Gene selected by MG-132: 729
# Gene selected by epirubicin: 4893
# Gene selected by panobinostat: 905
# Gene selected by PHA-793887: 4067
# Gene selected by mitoxantrone: 1889
#                     col_med  gene_count  significant
# CD4_naive          0.054868       584.0     0.054868
# CD8_naive         -0.049564       527.0     0.000000
# Tc                -0.076477       603.0    -0.076477
# Tex               -0.079292       585.0    -0.079292
# Tr1                0.052383       624.0     0.052383
# nTreg             -0.041931       530.0     0.000000
# iTreg             -0.062378       573.0    -0.062378
# Th1               -0.073703       563.0    -0.073703
# Th2                0.056077       592.0     0.056077
# Th17               0.040343       534.0     0.000000
# Tfh                0.080316       556.0     0.080316
# Tcm                0.089296       617.0     0.089296
# Tem               -0.084913       577.0    -0.084913
# NKT                0.065923       555.0     0.065923
# MAIT               0.031262       596.0     0.031262
# DC                -0.071216       600.0    -0.071216
# B_cell            -0.051503       554.0    -0.051503
# Monocyte          -0.082534       584.0    -0.082534
# Macrophage        -0.058020       557.0    -0.058020
# NK                 0.093439       566.0     0.093439
# Neutrophil        -0.072324       617.0    -0.072324
# Tgd                0.049403       530.0     0.000000
# CD4_T              0.107184       592.0     0.107184
# CD8_T             -0.082628       632.0    -0.082628
# InfiltrationScore  0.061645       607.0     0.061645
# withaferin-a
# Gene selected by withaferin-a: 1162
# <ipython-input-8-99815b7c30fb>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_